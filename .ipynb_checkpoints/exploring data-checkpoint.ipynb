# %%
import pandas as pd
import numpy as np
from scipy.integrate import solve_ivp, solve_bvp
from scipy.optimize import minimize
from matplotlib import pyplot as plt, dates
import datetime

# %%
cnty_df = pd.read_csv('us-counties.csv')
cnty_df.date = pd.to_datetime(cnty_df.date,format='%Y-%m-%d')

# %%
utah_mask = cnty_df.state == 'Utah'
salt_lake_mask = cnty_df.county == 'Salt Lake'
utah_cnty_mask = cnty_df.county == 'Utah'
utah_cnty_df = cnty_df[utah_cnty_mask]
salt_cnty_df = cnty_df[salt_lake_mask]
utah_st_df = cnty_df[utah_mask]

# %%
salt_cnty_df.plot(x='date',y='cases')
plt.show()

# %%
salt_cnty_df['new_cases'] = np.hstack([np.array([0]), np.diff(salt_cnty_df.cases.values)])
salt_cnty_df['roll'] = salt_cnty_df.new_cases.rolling(window=7).mean()
salt_cnty_df.plot(x='date',y='roll')
plt.show()
# Out:
# /home/ethan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/ethan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
utah_cnty_df['new_cases'] = np.hstack([np.array([0]), np.diff(utah_cnty_df.cases.values)])
utah_cnty_df['roll'] = utah_cnty_df.new_cases.rolling(window=7).mean()
utah_cnty_df.plot(x='date',y='roll')
utah_cnty_df.plot(x='date',y='new_cases')
utah_cnty_df.plot(x='date',y='cases')
plt.show()
# Out:
# /home/ethan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/ethan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
sumt_cnty_df = cnty_df[(cnty_df.county == 'Summit') & (utah_mask)]
sumt_cnty_df.plot(x='date', y='cases')
plt.show()

# %%
new_york_df = cnty_df[cnty_df.county == 'New York City']
# salt_lake_mask = cnty_df.county == 'Salt Lake'
new_york_df.plot(x='date', y='cases')
plt.show()

# %%
β = .25
γ = 1/10

t0 = 0
tf = 150
points = tf
t = np.linspace(t0,tf,points)
N = 8.399e6
I0 = 52

# this is using a SIR-A where A is asymptomatic. not too different from SIR but interesting
def diff(t, Y):
    S = Y[0]
    I = Y[1]
    R = Y[2]
    dS = -β*S*I
    dI = (β*S*I) - γ*I
    dR = γ*I
    return np.array([dS, dI, dR])


Y0 = np.array([(N-I0)/N, I0/N, 0])

sol = solve_ivp(diff, (t0,tf), Y0, t_eval=t).y

# plt.plot((1-sol[0])[:63])
# plt.plot(new_york_df.cases.values[11:]/N)
# plt.show()
plt.plot(t,sol[0],label='Susceptible',color='black')
plt.plot(t,sol[1],label='Infected',color='red')
plt.plot(t,sol[2],label='Recovered',color='blue')
plt.xlim(0,tf)
plt.ylim(0,1)
plt.title('Modeling Covid-19 in NYC')
plt.xlabel('Days since Mar 11')
plt.ylabel('Proportion of Population')
plt.legend()
plt.savefig('SIR2.pdf')
plt.show()

# %%
peak = N*max(sol[1])
58000-peak*.05
# Out:
# -40324.16802570876

# %%
def mini(x):
    α, Tg = x
    t0 = 1
    tf = 63
    points = tf
    t = np.linspace(t0,tf,points)
    N = 8.399e6
    I0 = 52

    def diff(t, Y):
        S = Y[0]
        I = Y[1]
        R = Y[2]
        dS = -(α/t)*I
        dI = (α/t - 1/Tg)*I
        dR = (1/Tg)*I
        return np.array([dS, dI, dR])


    Y0 = np.array([(N-I0)/N, I0/N, 0])

    sol = solve_ivp(diff, (t0,tf), Y0, t_eval=t).y
    return np.linalg.norm((1-sol[0]) - (new_york_df.cases.values[11:]/N))

#  1/10 is based on some articles I found that claim the 
# average length of time someone is sick is 10 days
# the model seems to always take the upper bound
x0 = (3.2, 22.8)

s = minimize(mini, x0, bounds=((0,20),(0,60)))
print(s)
# Out:
#       fun: 0.004394030793306137
#  hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#       jac: array([3.74960479e-07, 2.31585584e-08])
#   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 126
#       nit: 13
#    status: 0
#   success: True
#         x: array([ 2.55855111, 16.2333963 ])

# %%
# set parameters based on minimization
α, Tg = s.x

# time period
t0 = 1
tf = 150
points = tf
t = np.linspace(t0,tf,points)

# set NYC population and number of initial cases
# this number is based on the number of cases when
# NYC went into lockdown
N = 8.399e6
I0 = 52

# ODE
def diff(t, Y):
    S = Y[0]
    I = Y[1]
    R = Y[2]
#     This is the PGED model introduced in paper
    dS = -(α/t)*I
    dI = (α/t - 1/Tg)*I
    dR = (1/Tg)*I
    
    return np.array([dS, dI, dR])

# set initial cond
Y0 = np.array([(N-I0)/N, I0/N, 0])

sol = solve_ivp(diff, (t0,tf), Y0, t_eval=t).y

# plot the real world data
plt.figure(figsize=(10,4))
plt.plot(new_york_df.cases.values[11:]/N,label='Data')
# plot the modeled data
plt.plot(t[:63],(1-sol[0])[:63],label='1-S(t)')
plt.title('Modeling NYC covid cases with SIR')
plt.legend()
plt.xlabel('Days since Mar 11')
plt.ylabel('Proportion of Population')
plt.savefig('PGED-model.pdf',dpi=500)
plt.show()

plt.plot(t,1-sol[0],label='1-S')
plt.plot(t,sol[1],label='I')
plt.plot(t,sol[2],label='R')
plt.ylim(0,0.15)
plt.legend()
plt.title('Modeling NYC covid cases with SIR')
plt.show()

# %%
β, γ = 1/6, 1/10
t0 = 0
tf = 300
points = tf
t = np.linspace(t0,tf,points)
N = 8.399e6
I0 = 52

def diff(t, Y):
    S = Y[0]
    I = Y[1]
    R = Y[2]
    dS = -β*S*I
    dI = β*S*I - γ*I
    dR = γ*I
    return np.array([dS, dI, dR])


Y0 = np.array([(N-I0)/N, I0/N, 0])

sol = solve_ivp(diff, (t0,tf), Y0, t_eval=t).y
plt.plot(t,sol[0],label='S')
plt.plot(t,sol[1],label='I')
plt.plot(t,sol[2],label='R')
plt.show()

# %%
new_york_df
# Out:
#              date         county     state  fips   cases  deaths
# 416    2020-03-01  New York City  New York   NaN       1       0
# 448    2020-03-02  New York City  New York   NaN       1       0
# 482    2020-03-03  New York City  New York   NaN       2       0
# 518    2020-03-04  New York City  New York   NaN       2       0
# 565    2020-03-05  New York City  New York   NaN       4       0
# 627    2020-03-06  New York City  New York   NaN       5       0
# 715    2020-03-07  New York City  New York   NaN      12       0
# 820    2020-03-08  New York City  New York   NaN      14       0
# 947    2020-03-09  New York City  New York   NaN      20       0
# 1098   2020-03-10  New York City  New York   NaN      37       0
# 1285   2020-03-11  New York City  New York   NaN      52       0
# 1521   2020-03-12  New York City  New York   NaN      96       0
# 1814   2020-03-13  New York City  New York   NaN     155       0
# ...

# %%
xs = np.random.random(100)*10
ys = 1*xs**3 + 5*(xs**2 + 2*xs) + 8 + np.random.random(100)*.01

# %%
# define the function we want to minimize
def fun(p):
    a,b,d = p
    # get the model output based on the parameters
    out = a*xs**3 + b*(xs**2 + 2*xs) + d

    # find the difference between out and the data
    diff = out - ys

    # must return a float
    return np.linalg.norm(diff)

p0 = (1,1,1)

minimize(fun,p0)
# Out:
#       fun: 0.030195199478931276
#  hess_inv: array([[ 9.93601499e-08, -7.95439222e-07,  1.11975732e-05],
#        [-7.95439222e-07,  6.66836165e-06, -1.03333592e-04],
#        [ 1.11975732e-05, -1.03333592e-04,  2.19094931e-03]])
#       jac: array([7.14631565e-03, 9.05858586e-04, 9.93791036e-06])
#   message: 'Desired error not necessarily achieved due to precision loss.'
#      nfev: 582
#       nit: 24
#      njev: 114
#    status: 2
#   success: False
#         x: array([0.99999636, 5.00002704, 8.00448478])

# %%
new_york_df.to_csv('new_york_df.csv')
